# %% [markdown]
# # BMI Calculator

# %%
name = input("Enter you first name: ")

weight = input("Enter you weight in pounds: ")

height = input ("Enter you height in inches: ")

BMI = (weight * 703) / (height * height)
# Out:
# Enter you first name: Zsolt
# Enter you weight in pounds: 242
# Enter you height in inches: 70
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 7
#       3 weight = input("Enter you weight in pounds: ")
#       5 height = input ("Enter you height in inches: ")
# ----> 7 BMI = (weight * 703) / (height * height)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(height)
# Out:
# str

# %%
name = input("Enter you first name: ")

weight = int(input("Enter you weight in pounds: "))

height = int(input ("Enter you height in inches: "))

BMI = (weight * 703) / (height * height)

print(BMI)

if BMI > 0:
    if (BMI < 18.5):
        print(name + ", You are underweight!")
    elif (BMI <= 24.9):
        print(name + ", You are normal weight!")
    elif (BMI <= 29.0):
        print(name + ", You are overweight!")
    elif (BMI <= 34.9):
        print(name + ", You are obese!")
    elif (BMI <= 39.9):
        print(name + ", You are severly obese!")
    else:
        print(name + ", You are morbidly obese!")
else:
        print("Enter valid inputs")
# Out:
# Enter you first name: Zsolt
# Enter you weight in pounds: 230
# Enter you height in inches: 70
# 32.99795918367347
# Zsolt, You are obese!
